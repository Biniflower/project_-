# %% [markdown]
# ## 구글 플레이 스토어 '차이 코퍼레이션 앱 별점 리뷰' 웹 크롤링

# %%
#google-play-scraper python library

# !pip install google-play-scraper

# %%
# 라이브러리
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all, reviews

# %%
# url 입력
url_ck = "com.devsisters.ck"

# %%
app_ck= app(url_ck,
                  lang = "ko", # defaults = "en"
                  country = "kr" # defaults to "us"
                 )

# %%
review_df = pd.DataFrame(review_list, columns = ['score','content', 'date'])
print(len(review_df))
review_df.head()

# %%
# 데이터프레임 변환
#df_app_ck = pd.DataFrame.from_dict(app_ck, orient = "index").head(3)

# %%
# 차이코퍼레이션  앱 리뷰 크롤링
review_ck = reviews_all(url_ck,
                             sleep_milliseconds = 100,
                             lang = "ko",# default = "en"
                             country = "kr", # default = "US"
                             sort = Sort.MOST_RELEVANT, # Sort.NEWEST
                             filter_score_with = None # None means All score
                            )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # 차이코퍼레이션  앱 리뷰 크롤링
# ----> 2 review_ck = reviews_all(url_ck,
#       3                              sleep_milliseconds = 100,
#       4                              lang = "ko",# default = "en"
#       5                              country = "kr", # default = "US"
#       6                              sort = Sort.MOST_RELEVANT, # Sort.NEWEST
#       7                              filter_score_with = None # None means All score
#       8                             )
#
# File /opt/anaconda3/lib/python3.9/site-packages/google_play_scraper/features/reviews.py:129, in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     126 result = []
#     128 while True:
# --> 129     _result, continuation_token = reviews(
#     130         app_id,
#     131         count=MAX_COUNT_EACH_FETCH,
# ...

# %%
# 데이터프레임 변환
df_review_chai = pd.DataFrame(review_chai)
df_review_chai.head(1)
# Out:
#                                reviewId    userName  \
# 0  323acc95-4519-46f3-a8e4-2e48ff88f6f3  Jisong Lee
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0  내가 정말 잘했던 건 번개 미리 엄청 모아놓거나 잔액 한꺼번에 충전해놓지 않았던 것...      1            121
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0               3.17.0 2022-09-28 01:48:47         None       NaT

# %%
df_review_chai.head(10)
# Out:
#                                reviewId        userName  \
# 0  323acc95-4519-46f3-a8e4-2e48ff88f6f3      Jisong Lee
# 1  9e8e0850-2be7-490c-863d-3f48094212c0              연우
# 2  76658469-1529-43d5-b107-b56b0477f614             ᄋᄒᄌ
# 3  e54bb9f6-597c-49e0-b6f0-3202d4cb35b6             하해진
# 4  3f00a92c-ff9b-4d57-937e-4e32374e19f0              라이
# 5  068a5c32-3eaa-46cc-857f-bb57d4f5555e             박하미
# 6  07c34f5e-27cb-421c-93e6-9e84a81a2c22             정정정
# 7  afb6dc2f-ae4c-42dd-bff8-76c2924f31be  Jung moon Choi
# 8  2e521209-7b36-416f-9117-22c19e1f657a             지원문
# 9  2415c83c-52a3-4590-8798-d95a2ada20b6     ah reum eom
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...
# 1  https://play-lh.googleusercontent.com/a-/ACNPE...
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
# ...

# %%
df_review_chai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5825 entries, 0 to 5824
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              5825 non-null   object
#  1   userName              5825 non-null   object
#  2   userImage             5825 non-null   object
#  3   content               5825 non-null   object
#  4   score                 5825 non-null   int64
#  5   thumbsUpCount         5825 non-null   int64
#  6   reviewCreatedVersion  5456 non-null   object
#  7   at                    5825 non-null   datetime64[ns]
#  8   replyContent          1602 non-null   object
#  9   repliedAt             1602 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(6)
# memory usage: 455.2+ KB

# %%
df_review_chai['at'].head()
# Out:
# 0   2022-09-28 01:48:47
# 1   2022-07-31 20:53:54
# 2   2022-08-17 12:15:11
# 3   2022-08-03 00:40:35
# 4   2022-07-03 19:21:39
# Name: at, dtype: datetime64[ns]

# %%
df_review_chai['score'].unique()
# Out:
# array([1, 5, 2, 4, 3])

# %%
df_review_chai['content'].head(5)
# Out:
# 0    내가 정말 잘했던 건 번개 미리 엄청 모아놓거나 잔액 한꺼번에 충전해놓지 않았던 것...
# 1    7월부터 할인액, 퍼센트, 적용 가능 가맹점 등 혜택을 대폭 줄이고 사용해야하는 번...
# 2    번개 값은 2배에서 3배 가량 뛰고, 부스터 갯수도 확 줄어버린 것까진 괜찮습니다....
# 3    처음에는 혜택도 많았었고 번개 부스트 사용할 수 있는 곳도 많았었는데 어느새 보니 ...
# 4    전엔 안그랬는데 요즘엔 일반적인 부스트들이 너무 빨리 솔드아웃돼요. 실질적으로 번개...
# Name: content, dtype: object

# %%
df_review_chai['thumbsUpCount'].unique()
# Out:
# array([121,  70,  29,  42,  63,  26,  15,   7,  19,  11,   4,  20,   8,
#         10,   9,   5,   6,   0,  46, 126,   2,  25,   1,  16,  18,  36,
#         13,  21,   3,  27,  12,  34,  35,  17,  14,  24,  39,  22,  33,
#         49,  32,  41,  30,  28,  23,  37,  40,  71, 107,  51])

# %%
df_review_chai['thumbsUpCount']
# Out:
# 0       121
# 1        70
# 2        29
# 3        42
# 4        63
#        ...
# 5820      0
# 5821      0
# 5822      0
# 5823      0
# 5824      0
# Name: thumbsUpCount, Length: 5825, dtype: int64

# %%
df_2020_03 = df_review_chai[df_review_chai['at'].between('2019-08-01', '2020-03-31')]

# %%
df_2020_03.rename({'at':'날짜'}, axis=1,inplace=True)
df_2020_03.rename({'content':'리뷰내용'}, axis=1,inplace=True)
df_2020_03.rename({'score':'별점'}, axis=1,inplace=True)
df_2020_03.rename({'thumbsUpCount':'리뷰동조자수'}, axis=1,inplace=True)
# Out:
# /var/folders/s5/p9v5v4795132_w2y_ymwbtk80000gn/T/ipykernel_50825/3726897678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_03.rename({'at':'날짜'}, axis=1,inplace=True)
# /var/folders/s5/p9v5v4795132_w2y_ymwbtk80000gn/T/ipykernel_50825/3726897678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_03.rename({'content':'리뷰내용'}, axis=1,inplace=True)
# /var/folders/s5/p9v5v4795132_w2y_ymwbtk80000gn/T/ipykernel_50825/3726897678.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_2020_03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1162 entries, 37 to 5808
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              1162 non-null   object
#  1   userName              1162 non-null   object
#  2   userImage             1162 non-null   object
#  3   리뷰내용                  1162 non-null   object
#  4   별점                    1162 non-null   int64
#  5   리뷰동조자수                1162 non-null   int64
#  6   reviewCreatedVersion  1106 non-null   object
#  7   날짜                    1162 non-null   datetime64[ns]
#  8   replyContent          283 non-null    object
#  9   repliedAt             283 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(6)
# memory usage: 99.9+ KB

# %%
# 여러 컬럼 동시 접근

df_2020_03[['날짜','리뷰내용', '별점', '리뷰동조자수']]
# Out:
#                       날짜                                               리뷰내용  \
# 37   2020-03-20 13:27:47  앱은 좋습니다. 결제하기도 편리하구요. 딱 한가지 바라는게 있다면 저는 주로 티□에...
# 50   2020-01-19 13:51:57  이 어플이 좋은 점은 첫결제 이벤트가 차이 첫결제가 아닌 해당 가맹점에서 첫결제라 ...
# 51   2020-02-12 19:41:58  거의 초반부터 쭈욱 잘사용하고 있는 앱입니다. 초반때이기에 할인부분이나 페이백 지원...
# 56   2019-12-07 14:02:42  계좌 연동이 되어 좋습니다. 신용, 체크카드가 없는 사람도 쉽게 사용이 가능했습니다...
# 66   2020-01-30 18:28:24  자동충전 하려면 통장에 10만원 이상 있어야 되지만 자동충전해서 결제하면 캐시백 5...
# ...                  ...                                                ...
# 5733 2020-01-18 21:04:01                                                좋아요
# 5761 2020-02-22 10:46:12                                                좋네요
# 5777 2019-11-26 15:59:07                                                좋네요
# 5799 2019-08-26 17:21:14                                              쓰레기어플
# 5808 2019-08-04 02:06:58                                               good
#
#       별점  리뷰동조자수
# 37     4      36
# 50     5       2
# ...

# %%
df_2020_03= df_2020_03.to_excel('/Users/soon/Desktop/final_project_chai_review.xlsx', index=False)

# %%
df_review_chai1 = df_review_chai.to_csv('/Users/soon/Desktop/final_project_chai_review.txt', index=False)

# %% [markdown]
# ## 구글 플레이 스토어 '차이 코퍼레이션 앱 별점 리뷰' 텍스트 마이닝

# %%
# 한글자연어 처리 라이브러리 설치
# !pip install wordcloud

# %%
# !pip install nltk

# %%
from wordcloud import WordCloud
from konlpy.tag import Twitter
from collections import Counter

# %%
# 데이터 불러오기

file = open('/Users/soon/Desktop/final_project_chai_review.txt', 'r')

# %%
lists = file.readlines()

file.close()

# %%
lists
# Out:
# ['reviewId,userName,userImage,리뷰내용,별점,리뷰동조자수,reviewCreatedVersion,날짜,replyContent,repliedAt\n',
#  '323acc95-4519-46f3-a8e4-2e48ff88f6f3,Jisong Lee,https://play-lh.googleusercontent.com/a-/ACNPEu-2ynQssS4sStQ_OwlRDa3Lsn9JZLortY2iesdEIQ,"내가 정말 잘했던 건 번개 미리 엄청 모아놓거나 잔액 한꺼번에 충전해놓지 않았던 것. 이 세상 어떤 카드도 한 순간에 결제 혜택을 없애지 않음. 이제 없는 거나 마찬가지인 부스트로 합리적인 소비하라고 하는데, 번개 모으려고 카드 결제한 사람을 싸그리 무시하는 행태가 역겨울 지경.. 그 분들은 열심히 카드 이용한 대가가 사라진 거나 다름 없음. 그래놓고 한다는 답변이 죄다 자기 변명뿐.",1,121,3.17.0,2022-09-28 01:48:47,,\n',
# ...

# %%
twitter = Twitter()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/konlpy/tag/_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#코드 설명 , morphs = [] morphs라는 빈 리스트를 만들고 그 리스트에 추가(append)한다.

#무엇을? lists에 있는 글(sentence)의 형태소를 분석한(twitter) 결과를.  

morphs = []
 
for sentence in lists:
    morphs.append(twitter.pos(sentence))
    
print(morphs)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
noun_adj_adv_list=[]
 
for sentence in morphs :
    for word, tag in sentence :
        if tag in ['Noun'] and ("것" not in word) and ("내" not in word)and ("나" not in word)and ("수"not in word) and("게"not in word)and("말"not in word):
            noun_adj_adv_list.append(word)
            
print(noun_adj_adv_list)
# Out:
# ['리뷰', '점', '리뷰', '날짜', '건', '번개', '미리', '잔액', '번', '충전', '이', '세상', '카드', '순간', '결제', '혜택', '이제', '마찬가지', '부스트', '합리', '소비', '번개', '카드', '결제', '사람', '무시', '행태', '지경', '그', '분', '카드', '이용', '대가', '답변', '자기', '변명', '연우', '할인', '액', '퍼센트', '적용', '가능', '가맹', '점', '등', '혜택', '대폭', '줄', '사용', '번개', '공지', '부분', '번개', '유효', '기간', '재발', '번개', '웰컴', '번개', '부스트', '모두', '솔드아웃', '새벽', '마찬가지', '타', '카드', '비교', '사용', '범위', '캐시', '백도', '보유', '번개', '사용', '다시', '일', '사용', '저', '초반', '혜택', '생각', '사용', '대폭', '감소', '예정', '미리', '공지', '차이', '부스트', '프로모션', '혜택', '좀더', '현실', '방안', '재', '조정', '그', '과정', '혜택', '축소', '점', '다만', '카드', '등', '비', '기존', '혜택', '과', '점', '등', '감안', '재', '조정', '보시', '혜택', '축소', '고객', '따라서', '카드', '혜택', '비교', '합리', '선택', '생각', '다만', '앞', '기존', '혜택', '제공', '하니', '이용', '부스트', '통해', '합리', '소비', '추가', '부스트', '혜택', '프로모션', '매번', '변동성', '대상', '참고', '번개', '값', '배', '배', '가량', '부스터', '확', '차이', '카드', '함', '번개', '적립', '사용', '정체', '요즘', '번개', '실질', '사용', '부스터', '타', '카드', '비교', '우위', '강점', '애용'
# ...

# %%
#Counter는 위에서 말했듯이 카운팅 해주는 패키지.  이를 내가 만든 최종 리스트(noun_adj_adv_list)에 적용시킨다. 

#리스트에서 빈도수대로 단어를 정렬(most_common)하고 이를 딕셔너리(dict) 형태로 출력한다.




count = Counter(noun_adj_adv_list)

# %%
words = dict(count.most_common())

# %%
words
# Out:
# {'차이': 3442,
#  '혜택': 1790,
#  '사용자': 1684,
#  '할인': 1608,
#  '결제': 1336,
#  '고객': 1261,
#  '사용': 1098,
#  '앱': 953,
#  '이용': 689,
#  '부스트': 683,
#  '카드': 659,
#  '점': 591,
#  '센터': 556,
#  '계좌': 549,
#  '번개': 499,
#  '적립': 484,
#  '더': 462,
#  '은행': 443,
#  '확인': 411,
#  '등': 409,
#  '불편': 393,
#  '로': 388,
#  '등록': 354,
#  '충전': 326,
#  '재': 305,
#  '앞': 301,
#  '조정': 294,
#  '인증': 293,
#  '시': 288,
#  '자동': 285,
#  '때': 283,
#  '기존': 271,
#  '제공': 257,
#  '금액': 254,
#  '프로모션': 253,
#  '문의': 252,
#  '통해': 249,
#  '왜': 246,
#  '해당': 245,
#  '부분': 244,
#  '쿠폰': 242,
#  '티몬': 238,
#  '서비스': 233,
#  '노력': 230,
#  '우선': 227,
#  '후': 225,
#  '다시': 224,
#  '좀더': 217,
#  '캐시': 215,
#  '계속': 214,
#  '가맹': 211,
#  '연락': 210,
#  '다른': 207,
#  '그': 203,
#  '어플': 203,
#  '적용': 202,
#  '환불': 198,
#  '굿': 197,
#  '현재': 195,
#  '삭제': 193,
#  '예정': 184,
#  '인': 183,
#  '다만': 179,
#  '추가': 178,
#  '거': 178,
#  '문제': 175,
#  '업데이트': 175,
#  '경우': 174,
#  '가입': 173,
#  '참고': 171,
#  '번호': 171,
# ...

# %%
from wordcloud import WordCloud 

import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from PIL import *

# %%
# %matplotlib inline

import matplotlib
from IPython.display import set_matplotlib_formats
matplotlib.rc('font',family = 'Malgun Gothic')

set_matplotlib_formats('retina')

matplotlib.rc('axes',unicode_minus = False)
# Out:
# /var/folders/s5/p9v5v4795132_w2y_ymwbtk80000gn/T/ipykernel_50825/1842996813.py:7: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
#워드클라우드의 모양 설정. 원모양의 이미지를 그대로 가져와 만들도록 하였음.
cand_mask=np.array(Image.open('circle.png'))

# %%
wordcloud = WordCloud(
    font_path = '/Library/Fonts/AppleSDGothicNeo.ttc',    # 맥에선 한글폰트 설정 잘해야함.
    background_color='white',                             # 배경 색깔 정하기
    colormap = 'Blues', 
    mask=cand_mask,# 폰트 색깔 정하기
    width = 800,
    height = 800
)


wordcloud_words = wordcloud.generate_from_frequencies(words)

# %%
array = wordcloud.to_array()
print(type(array)) # numpy.ndarray
print(array.shape) # (800, 800, 3)

fig = plt.figure(figsize=(10, 10))
plt.imshow(array, interpolation="bilinear")
plt.axis('off')
plt.show()
fig.savefig('business_anlytics_worldcloud.png')
# Out:
# <class 'numpy.ndarray'>
# (401, 390, 3)

# %%
df = pd.DataFrame(words, index=[0])

# %%
words = df.T.reset_index()
words
# Out:
#      index     0
# 0       차이  3442
# 1       혜택  1790
# 2      사용자  1684
# 3       할인  1608
# 4       결제  1336
# ...    ...   ...
# 6273    최규     1
# 6274    재욱     1
# 6275   홍성훈     1
# 6276   김효정     1
# 6277   이우주     1
#
# [6278 rows x 2 columns]

# %%
words.columns = ['연관어', '빈도수']
words.columns
# Out:
# Index(['연관어', '빈도수'], dtype='object')

# %%
words.loc[:, '빈도수순위'] = words.loc[:, '빈도수'].rank(axis=0, method='min', ascending=False)
words_test = words.sort_values(by=['빈도수순위'], ascending=True, ignore_index=False, inplace=False)

# %%
words_test.head(20)
# Out:
#     연관어   빈도수  빈도수순위
# 0    차이  3442    1.0
# 1    혜택  1790    2.0
# 2   사용자  1684    3.0
# 3    할인  1608    4.0
# 4    결제  1336    5.0
# 5    고객  1261    6.0
# 6    사용  1098    7.0
# 7     앱   953    8.0
# 8    이용   689    9.0
# 9   부스트   683   10.0
# 10   카드   659   11.0
# 11    점   591   12.0
# 12   센터   556   13.0
# 13   계좌   549   14.0
# 14   번개   499   15.0
# 15   적립   484   16.0
# 16    더   462   17.0
# 17   은행   443   18.0
# 18   확인   411   19.0
# 19    등   409   20.0
